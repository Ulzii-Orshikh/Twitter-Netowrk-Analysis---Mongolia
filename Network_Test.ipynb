# %%
import pandas as pd 
import matplotlib.pyplot as plt 
import matplotlib
import networkx as nx

# %%
fig, ax = plt.subplots(figsize=(15,8))

relationships = pd.DataFrame({'from': ['BattulgaKh','Asashoryu', 'Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','Asashoryu','elbegdorj','elbegdorj','elbegdorj','elbegdorj','elbegdorj','elbegdorj','elbegdorj','elbegdorj','jargal_defacto','jargal_defacto','jargal_defacto','jargal_defacto','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','oyunlt','enkhboldz', 'enkhboldz','enkhboldz','enkhboldz','enkhboldz','enkhboldz','enkhboldz','enkhboldz','enkhboldz','enkhboldz'], 
                              'to':   ['Uyanga_ts','BattulgaKh','elbegdorj','jargal_defacto','enkhboldz','Baabarniitlelch','enkhbat','ganhuyag','DorjsurenBold','OtgonbayarY','m_zorigt','tsbat_IT','enkhamgalanmp','Tsandeleg_L','TsogtgerelB','TsogtbaatarD','batzayased','UKhurelsukh','AminaMongolia','BattulgaKh','enkhboldz','Baabarniitlelch','tsbat_IT','TsogtgerelB','batzayased','UKhurelsukh','KhishigtogtohTs','Baabarniitlelch','enkhbat','OtgonbayarY','enkhamgalanmp','BattulgaKh','Asashoryu','elbegdorj','jargal_defacto','enkhboldz','Baabarniitlelch','enkhbat','ganhuyag','DorjsurenBold','OtgonbayarY','m_zorigt','tsbat_IT','enkhamgalanmp','Uyanga_ts','Aanxaa','Tsandeleg_L','TsogtgerelB','TsogtbaatarD','batzayased','UKhurelsukh','BattulgaKh','jargal_defacto','enkhbat','ganhuyag','OtgonbayarY',
'tsbat_IT','enkhamgalanmp','TsogtgerelB','UKhurelsukh','ts_baatarkhuu'

]})

carac = pd.DataFrame({'ID':['BattulgaKh', 'Uyanga_ts', 'Asashoryu', 'elbegdorj','jargal_defacto','enkhboldz','Baabarniitlelch','enkhbat','ganhuyag','DorjsurenBold','OtgonbayarY','m_zorigt','tsbat_IT','enkhamgalanmp','Tsandeleg_L','TsogtgerelB','TsogtbaatarD','batzayased','UKhurelsukh','AminaMongolia','KhishigtogtohTs','oyunlt','Aanxaa','ts_baatarkhuu'], 
                      'type':['Politic','Business','Sport', 'Politic', 'Media', 'Politic', 'Media', 'Business', 'Business', 'Artist', 'Politic', 'Politic','Business','Politic','Sport','Politic','Politic','Artist', 'Politic','Business','Media','Politic','Media', 'Business']})

followers_raw = pd.read_csv('followers.csv')
followers = [int(n) for n in followers_raw.Followers]

size = [2486, 970, 3029, 2486, 2462, 2341, 2228,2072, 2045,1696, 1572,1551, 1321,1276, 659,631, 550,522, 436,413, 298,2402, 694, 420]

G = nx.from_pandas_edgelist(relationships, 'from', 'to', create_using=nx.Graph())

carac = carac.set_index('ID')
carac = carac.reindex(G.nodes())
carac['type'] = pd.Categorical(carac['type'])
carac['type'].cat.codes

cmap = matplotlib.colors.ListedColormap(['palegreen', 'royalblue', 'turquoise', 'salmon', 'orange'])

nx.draw(G, with_labels=True, node_color = carac['type'].cat.codes, node_size = size, cmap = cmap)
